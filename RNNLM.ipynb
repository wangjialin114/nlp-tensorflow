# %%
import tensorflow as tf

# %%
help(tf.c)
# Out:
# ---------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-6-20f3f01441f3> in <module>()
# ----> 1 help(tf.collection)
#
# AttributeError: 'module' object has no attribute 'collection'
